# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 631

# %%
# 6.2.6 Get city weather data.
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
set_count = 1
record_count = 1

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(30)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | zhuji
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | suao
# City not found. Skipping...
# Processing Record 11 of Set 1 | san quintin
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | nemuro
# Processing Record 15 of Set 1 | vila do maio
# Processing Record 16 of Set 1 | andenes
# Processing Record 17 of Set 1 | saint-michel-des-saints
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | beringovskiy
# Processing Record 20 of Set 1 | antsohihy
# Processing Record 21 of Set 1 | araouane
# Processing Record 22 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | san policarpo
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | nosy varika
# Processing Record 27 of Set 1 | hasaki
# Processing Record 28 of Set 1 | kampot
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | chernyshevskiy
# Processing Record 34 of Set 1 | mbandaka
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 1 | itoman
# Processing Record 39 of Set 1 | nanortalik
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | inta
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | gainesville
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | barcelos
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 50 of Set 1 | turayf
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | laguna
# Processing Record 3 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 4 of Set 2 | superior
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 2 | luganville
# Processing Record 8 of Set 2 | nizhniy kuranakh
# Processing Record 9 of Set 2 | hambantota
# Processing Record 10 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 11 of Set 2 | griffith
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | yokadouma
# Processing Record 14 of Set 2 | port arthur
# Processing Record 15 of Set 2 | sorland
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | srivardhan
# Processing Record 19 of Set 2 | palembang
# Processing Record 20 of Set 2 | portland
# Processing Record 21 of Set 2 | constitucion
# Processing Record 22 of Set 2 | caravelas
# Processing Record 23 of Set 2 | krasnoarmeyskoye
# Processing Record 24 of Set 2 | padang
# Processing Record 25 of Set 2 | ostrovnoy
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | tuatapere
# Processing Record 28 of Set 2 | gornyy
# Processing Record 29 of Set 2 | parnamirim
# Processing Record 30 of Set 2 | provideniya
# Processing Record 31 of Set 2 | kaitangata
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | souillac
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | kihei
# Processing Record 36 of Set 2 | cabadiangan
# Processing Record 37 of Set 2 | saint-leu
# Processing Record 38 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | georgetown
# Processing Record 42 of Set 2 | kaseda
# Processing Record 43 of Set 2 | klungkung
# Processing Record 44 of Set 2 | uruacu
# Processing Record 45 of Set 2 | pitimbu
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | kaeo
# Processing Record 49 of Set 2 | xinqing
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | igarka
# Processing Record 4 of Set 3 | chardara
# Processing Record 5 of Set 3 | rikitea
# Processing Record 6 of Set 3 | severo-kurilsk
# Processing Record 7 of Set 3 | ilulissat
# Processing Record 8 of Set 3 | rawson
# Processing Record 9 of Set 3 | inhambane
# Processing Record 10 of Set 3 | bubaque
# Processing Record 11 of Set 3 | pervomayskoye
# Processing Record 12 of Set 3 | longyan
# Processing Record 13 of Set 3 | cidreira
# Processing Record 14 of Set 3 | ilorin
# Processing Record 15 of Set 3 | ponta delgada
# Processing Record 16 of Set 3 | acarau
# Processing Record 17 of Set 3 | ous
# Processing Record 18 of Set 3 | vegreville
# Processing Record 19 of Set 3 | morondava
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | santa maria
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | mackenzie
# Processing Record 24 of Set 3 | ha tinh
# Processing Record 25 of Set 3 | richards bay
# Processing Record 26 of Set 3 | raga
# Processing Record 27 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 3 | jabinyanah
# Processing Record 29 of Set 3 | asau
# Processing Record 30 of Set 3 | hapur
# Processing Record 31 of Set 3 | chuy
# Processing Record 32 of Set 3 | enshi
# Processing Record 33 of Set 3 | kaduna
# Processing Record 34 of Set 3 | barrow
# Processing Record 35 of Set 3 | batagay-alyta
# Processing Record 36 of Set 3 | champaign
# Processing Record 37 of Set 3 | callaway
# Processing Record 38 of Set 3 | malindi
# Processing Record 39 of Set 3 | svobodnyy
# Processing Record 40 of Set 3 | hilo
# Processing Record 41 of Set 3 | olafsvik
# Processing Record 42 of Set 3 | tha muang
# Processing Record 43 of Set 3 | atar
# Processing Record 44 of Set 3 | williston
# Processing Record 45 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | dhidhdhoo
# Processing Record 48 of Set 3 | bijapur
# Processing Record 49 of Set 3 | mogadishu
# Processing Record 50 of Set 3 | port hardy
# Processing Record 1 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 2 of Set 4 | atuona
# Processing Record 3 of Set 4 | haukipudas
# Processing Record 4 of Set 4 | mahajanga
# Processing Record 5 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | batticaloa
# Processing Record 8 of Set 4 | flinders
# Processing Record 9 of Set 4 | butaritari
# Processing Record 10 of Set 4 | debre sina
# Processing Record 11 of Set 4 | menongue
# Processing Record 12 of Set 4 | bathsheba
# Processing Record 13 of Set 4 | mahaicony
# City not found. Skipping...
# Processing Record 14 of Set 4 | bambous virieux
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | ayer itam
# City not found. Skipping...
# Processing Record 17 of Set 4 | tymovskoye
# Processing Record 18 of Set 4 | suntar
# Processing Record 19 of Set 4 | katsuura
# Processing Record 20 of Set 4 | timmins
# Processing Record 21 of Set 4 | khash
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | khorramabad
# Processing Record 24 of Set 4 | kavaratti
# Processing Record 25 of Set 4 | sokoto
# Processing Record 26 of Set 4 | kununurra
# Processing Record 27 of Set 4 | newberg
# Processing Record 28 of Set 4 | bousso
# Processing Record 29 of Set 4 | laurel
# Processing Record 30 of Set 4 | yumen
# Processing Record 31 of Set 4 | novaya tavolzhanka
# Processing Record 32 of Set 4 | maloy
# Processing Record 33 of Set 4 | metro
# Processing Record 34 of Set 4 | rocha
# Processing Record 35 of Set 4 | tommot
# Processing Record 36 of Set 4 | mollendo
# Processing Record 37 of Set 4 | carnarvon
# Processing Record 38 of Set 4 | vila velha
# Processing Record 39 of Set 4 | niamey
# Processing Record 40 of Set 4 | havre-saint-pierre
# Processing Record 41 of Set 4 | marsh harbour
# Processing Record 42 of Set 4 | yenagoa
# Processing Record 43 of Set 4 | yelan
# Processing Record 44 of Set 4 | port hedland
# Processing Record 45 of Set 4 | bereda
# Processing Record 46 of Set 4 | kamenka
# Processing Record 47 of Set 4 | hami
# Processing Record 48 of Set 4 | sibolga
# Processing Record 49 of Set 4 | cockburn town
# Processing Record 50 of Set 4 | chokurdakh
# Processing Record 1 of Set 5 | quatre cocos
# Processing Record 2 of Set 5 | airai
# Processing Record 3 of Set 5 | middelburg
# Processing Record 4 of Set 5 | viedma
# Processing Record 5 of Set 5 | nouadhibou
# Processing Record 6 of Set 5 | gorontalo
# Processing Record 7 of Set 5 | kalmunai
# Processing Record 8 of Set 5 | vila
# Processing Record 9 of Set 5 | bredasdorp
# Processing Record 10 of Set 5 | trincomalee
# Processing Record 11 of Set 5 | asfi
# Processing Record 12 of Set 5 | champerico
# Processing Record 13 of Set 5 | torbay
# Processing Record 14 of Set 5 | moerai
# Processing Record 15 of Set 5 | tornio
# Processing Record 16 of Set 5 | tambovka
# Processing Record 17 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 5 | chippewa falls
# Processing Record 19 of Set 5 | biloela
# Processing Record 20 of Set 5 | aykhal
# Processing Record 21 of Set 5 | camacha
# Processing Record 22 of Set 5 | vao
# Processing Record 23 of Set 5 | marawi
# Processing Record 24 of Set 5 | kuminskiy
# Processing Record 25 of Set 5 | mabaruma
# Processing Record 26 of Set 5 | hervey bay
# Processing Record 27 of Set 5 | noumea
# Processing Record 28 of Set 5 | minab
# Processing Record 29 of Set 5 | hanzhong
# Processing Record 30 of Set 5 | east london
# Processing Record 31 of Set 5 | iqaluit
# Processing Record 32 of Set 5 | nang rong
# Processing Record 33 of Set 5 | necochea
# Processing Record 34 of Set 5 | kasempa
# Processing Record 35 of Set 5 | vestmannaeyjar
# Processing Record 36 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 5 | jalu
# Processing Record 38 of Set 5 | bengkulu
# Processing Record 39 of Set 5 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | port-gentil
# Processing Record 41 of Set 5 | charters towers
# Processing Record 42 of Set 5 | salinopolis
# Processing Record 43 of Set 5 | upernavik
# Processing Record 44 of Set 5 | buala
# Processing Record 45 of Set 5 | mareeba
# Processing Record 46 of Set 5 | kuching
# Processing Record 47 of Set 5 | kasongo-lunda
# Processing Record 48 of Set 5 | dali
# Processing Record 49 of Set 5 | chapais
# Processing Record 50 of Set 5 | santiago de cao
# Processing Record 1 of Set 6 | ancud
# Processing Record 2 of Set 6 | nuevo progreso
# Processing Record 3 of Set 6 | matara
# Processing Record 4 of Set 6 | klaksvik
# Processing Record 5 of Set 6 | petropavl
# Processing Record 6 of Set 6 | progreso
# Processing Record 7 of Set 6 | yeppoon
# Processing Record 8 of Set 6 | hay river
# Processing Record 9 of Set 6 | conceicao do araguaia
# Processing Record 10 of Set 6 | valparaiso
# Processing Record 11 of Set 6 | talnakh
# Processing Record 12 of Set 6 | calbuco
# Processing Record 13 of Set 6 | road town
# Processing Record 14 of Set 6 | mandera
# Processing Record 15 of Set 6 | faanui
# Processing Record 16 of Set 6 | roebourne
# Processing Record 17 of Set 6 | assai
# Processing Record 18 of Set 6 | codrington
# Processing Record 19 of Set 6 | homburg
# Processing Record 20 of Set 6 | kuva
# City not found. Skipping...
# Processing Record 21 of Set 6 | dalvik
# Processing Record 22 of Set 6 | victoria
# Processing Record 23 of Set 6 | okakarara
# Processing Record 24 of Set 6 | krasnoselkup
# Processing Record 25 of Set 6 | gardan diwal
# City not found. Skipping...
# Processing Record 26 of Set 6 | tahe
# Processing Record 27 of Set 6 | ruidoso
# Processing Record 28 of Set 6 | gat
# Processing Record 29 of Set 6 | kunming
# Processing Record 30 of Set 6 | rovaniemi
# Processing Record 31 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 6 | lompoc
# Processing Record 33 of Set 6 | muros
# Processing Record 34 of Set 6 | syamzha
# Processing Record 35 of Set 6 | matlock
# Processing Record 36 of Set 6 | ormond beach
# Processing Record 37 of Set 6 | ternate
# Processing Record 38 of Set 6 | zabaykalsk
# Processing Record 39 of Set 6 | datong
# Processing Record 40 of Set 6 | los llanos de aridane
# Processing Record 41 of Set 6 | narsaq
# Processing Record 42 of Set 6 | tiksi
# Processing Record 43 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 6 | teguise
# Processing Record 45 of Set 6 | komsomolskiy
# Processing Record 46 of Set 6 | trelew
# Processing Record 47 of Set 6 | acapulco
# Processing Record 48 of Set 6 | cervo
# Processing Record 49 of Set 6 | kailasahar
# City not found. Skipping...
# Processing Record 50 of Set 6 | onega
# Processing Record 1 of Set 7 | marshall
# Processing Record 2 of Set 7 | khatanga
# Processing Record 3 of Set 7 | nador
# Processing Record 4 of Set 7 | aklavik
# Processing Record 5 of Set 7 | sal rei
# Processing Record 6 of Set 7 | kahului
# Processing Record 7 of Set 7 | pahrump
# Processing Record 8 of Set 7 | kieta
# Processing Record 9 of Set 7 | arroyohondo
# Processing Record 10 of Set 7 | luderitz
# Processing Record 11 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 7 | naze
# Processing Record 13 of Set 7 | pusad
# Processing Record 14 of Set 7 | kodiak
# Processing Record 15 of Set 7 | dashitou
# Processing Record 16 of Set 7 | saint-georges
# Processing Record 17 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 7 | kushima
# Processing Record 19 of Set 7 | esperance
# Processing Record 20 of Set 7 | muriwai beach
# Processing Record 21 of Set 7 | kez
# Processing Record 22 of Set 7 | iskateley
# Processing Record 23 of Set 7 | davila
# Processing Record 24 of Set 7 | luan
# Processing Record 25 of Set 7 | namatanai
# Processing Record 26 of Set 7 | coihaique
# Processing Record 27 of Set 7 | fort-shevchenko
# Processing Record 28 of Set 7 | beloha
# Processing Record 29 of Set 7 | pochutla
# Processing Record 30 of Set 7 | yelatma
# Processing Record 31 of Set 7 | acajutla
# Processing Record 32 of Set 7 | bere
# Processing Record 33 of Set 7 | taltal
# Processing Record 34 of Set 7 | safaga
# Processing Record 35 of Set 7 | nkhotakota
# Processing Record 36 of Set 7 | asyut
# Processing Record 37 of Set 7 | margate
# Processing Record 38 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 7 | daru
# Processing Record 40 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 7 | fremont
# Processing Record 42 of Set 7 | ketchikan
# Processing Record 43 of Set 7 | fonte boa
# Processing Record 44 of Set 7 | kibondo
# Processing Record 45 of Set 7 | chiredzi
# Processing Record 46 of Set 7 | bembereke
# Processing Record 47 of Set 7 | meulaboh
# Processing Record 48 of Set 7 | okhotsk
# Processing Record 49 of Set 7 | palimbang
# Processing Record 50 of Set 7 | nova olimpia
# Processing Record 1 of Set 8 | novosil
# Processing Record 2 of Set 8 | saldanha
# Processing Record 3 of Set 8 | college
# Processing Record 4 of Set 8 | malanje
# Processing Record 5 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 8 | rundu
# Processing Record 8 of Set 8 | willowmore
# Processing Record 9 of Set 8 | ewa beach

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
# Reorder columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
new_city_data_df = city_data_df[new_column_order]
new_city_data_df

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
