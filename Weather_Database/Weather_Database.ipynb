# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 743

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),                         
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | chokurdakh
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | tura
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 1 | behbahan
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | lavrentiya
# Processing Record 15 of Set 1 | anadyr
# Processing Record 16 of Set 1 | fairbanks
# Processing Record 17 of Set 1 | poum
# Processing Record 18 of Set 1 | maceio
# Processing Record 19 of Set 1 | mahebourg
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | lagoa
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 1 | matay
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | the valley
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | sao joao da barra
# Processing Record 31 of Set 1 | vila franca do campo
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | hanna
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | college
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | paamiut
# Processing Record 38 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 1 | manta
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | isangel
# Processing Record 42 of Set 1 | imbituba
# Processing Record 43 of Set 1 | karratha
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | fougamou
# Processing Record 46 of Set 1 | lorengau
# Processing Record 47 of Set 1 | huarmey
# Processing Record 48 of Set 1 | honiara
# Processing Record 49 of Set 1 | linqiong
# Processing Record 50 of Set 1 | lasa
# Processing Record 1 of Set 2 | najran
# Processing Record 2 of Set 2 | bambous virieux
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | namibe
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | tsumeb
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | huaibei
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | esperance
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | sao miguel do araguaia
# Processing Record 18 of Set 2 | pervomayskoye
# Processing Record 19 of Set 2 | bac lieu
# Processing Record 20 of Set 2 | kaitangata
# Processing Record 21 of Set 2 | katsuura
# Processing Record 22 of Set 2 | netrakona
# Processing Record 23 of Set 2 | oistins
# Processing Record 24 of Set 2 | mount isa
# Processing Record 25 of Set 2 | torbay
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 28 of Set 2 | bethel
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | clarence town
# Processing Record 31 of Set 2 | barao de melgaco
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | chara
# Processing Record 34 of Set 2 | warrington
# Processing Record 35 of Set 2 | chardara
# Processing Record 36 of Set 2 | beringovskiy
# Processing Record 37 of Set 2 | tsnori
# Processing Record 38 of Set 2 | komsomolskiy
# Processing Record 39 of Set 2 | junqueiropolis
# Processing Record 40 of Set 2 | port lincoln
# Processing Record 41 of Set 2 | minas de barroteran
# Processing Record 42 of Set 2 | kuanshan
# City not found. Skipping...
# Processing Record 43 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 2 | mareeba
# Processing Record 45 of Set 2 | new norfolk
# Processing Record 46 of Set 2 | lexington park
# Processing Record 47 of Set 2 | coquimbo
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | mehamn
# Processing Record 50 of Set 2 | indramayu
# Processing Record 1 of Set 3 | umm kaddadah
# Processing Record 2 of Set 3 | aklavik
# Processing Record 3 of Set 3 | puerto escondido
# Processing Record 4 of Set 3 | faanui
# Processing Record 5 of Set 3 | fryanovo
# Processing Record 6 of Set 3 | makakilo city
# Processing Record 7 of Set 3 | poprad
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | mandalgovi
# Processing Record 11 of Set 3 | orocue
# Processing Record 12 of Set 3 | touros
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | san patricio
# Processing Record 15 of Set 3 | dikson
# Processing Record 16 of Set 3 | hilo
# Processing Record 17 of Set 3 | alofi
# Processing Record 18 of Set 3 | coahuayana
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | russell
# Processing Record 21 of Set 3 | puerto del rosario
# Processing Record 22 of Set 3 | erzin
# Processing Record 23 of Set 3 | san-pedro
# Processing Record 24 of Set 3 | north bend
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | saldanha
# Processing Record 27 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 3 | provideniya
# Processing Record 29 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 3 | walvis bay
# Processing Record 31 of Set 3 | ventspils
# Processing Record 32 of Set 3 | okhotsk
# Processing Record 33 of Set 3 | victoria
# Processing Record 34 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 3 | portland
# Processing Record 36 of Set 3 | yoichi
# Processing Record 37 of Set 3 | yulara
# Processing Record 38 of Set 3 | cheyenne
# Processing Record 39 of Set 3 | powassan
# Processing Record 40 of Set 3 | bubaque
# Processing Record 41 of Set 3 | guerrero negro
# Processing Record 42 of Set 3 | novikovo
# Processing Record 43 of Set 3 | cairns
# Processing Record 44 of Set 3 | saint-francois
# Processing Record 45 of Set 3 | port blair
# Processing Record 46 of Set 3 | havelock
# Processing Record 47 of Set 3 | verkhnevilyuysk
# Processing Record 48 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 3 | chapais
# Processing Record 50 of Set 3 | kraskino
# Processing Record 1 of Set 4 | lompoc
# Processing Record 2 of Set 4 | leningradskiy
# Processing Record 3 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 4 | iqaluit
# Processing Record 5 of Set 4 | hermanus
# Processing Record 6 of Set 4 | olafsvik
# Processing Record 7 of Set 4 | eureka
# Processing Record 8 of Set 4 | kailua
# Processing Record 9 of Set 4 | chom bung
# City not found. Skipping...
# Processing Record 10 of Set 4 | wanning
# Processing Record 11 of Set 4 | christiana
# Processing Record 12 of Set 4 | ponta delgada
# Processing Record 13 of Set 4 | griffith
# Processing Record 14 of Set 4 | elat
# Processing Record 15 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 4 | vacaria
# Processing Record 18 of Set 4 | faya
# Processing Record 19 of Set 4 | vaini
# Processing Record 20 of Set 4 | santiago del estero
# Processing Record 21 of Set 4 | burica
# City not found. Skipping...
# Processing Record 22 of Set 4 | kinanah
# City not found. Skipping...
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | viseu
# Processing Record 25 of Set 4 | oppdal
# Processing Record 26 of Set 4 | hami
# Processing Record 27 of Set 4 | oyama
# Processing Record 28 of Set 4 | fort wellington
# Processing Record 29 of Set 4 | ahipara
# Processing Record 30 of Set 4 | mar del plata
# Processing Record 31 of Set 4 | nishihara
# Processing Record 32 of Set 4 | noumea
# Processing Record 33 of Set 4 | zaozerne
# Processing Record 34 of Set 4 | iwanai
# Processing Record 35 of Set 4 | isiro
# Processing Record 36 of Set 4 | ussel
# Processing Record 37 of Set 4 | fortuna
# Processing Record 38 of Set 4 | felanitx
# Processing Record 39 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 4 | talnakh
# Processing Record 41 of Set 4 | madras
# Processing Record 42 of Set 4 | jaciara
# Processing Record 43 of Set 4 | brigantine
# Processing Record 44 of Set 4 | rantoul
# Processing Record 45 of Set 4 | gat
# Processing Record 46 of Set 4 | mount gambier
# Processing Record 47 of Set 4 | butaritari
# Processing Record 48 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 4 | narsaq
# Processing Record 50 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 5 | lake city
# Processing Record 2 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 5 | saint-philippe
# Processing Record 4 of Set 5 | kosh-agach
# Processing Record 5 of Set 5 | iracoubo
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | nome
# Processing Record 8 of Set 5 | tessalit
# Processing Record 9 of Set 5 | san cristobal
# Processing Record 10 of Set 5 | cherskiy
# Processing Record 11 of Set 5 | broken hill
# Processing Record 12 of Set 5 | pisco
# Processing Record 13 of Set 5 | nizhniy ingash
# Processing Record 14 of Set 5 | upington
# Processing Record 15 of Set 5 | baracoa
# Processing Record 16 of Set 5 | arlit
# Processing Record 17 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 5 | ugoofaaru
# Processing Record 19 of Set 5 | acaponeta
# Processing Record 20 of Set 5 | qingyuan
# Processing Record 21 of Set 5 | timra
# Processing Record 22 of Set 5 | ixtapa
# Processing Record 23 of Set 5 | edson
# Processing Record 24 of Set 5 | upernavik
# Processing Record 25 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 5 | nanortalik
# Processing Record 27 of Set 5 | anapskaya
# Processing Record 28 of Set 5 | odienne
# Processing Record 29 of Set 5 | avera
# Processing Record 30 of Set 5 | tiznit
# Processing Record 31 of Set 5 | karoi
# Processing Record 32 of Set 5 | bathsheba
# Processing Record 33 of Set 5 | mezen
# Processing Record 34 of Set 5 | bandarbeyla
# Processing Record 35 of Set 5 | dutse
# Processing Record 36 of Set 5 | alta floresta
# Processing Record 37 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 38 of Set 5 | kavieng
# Processing Record 39 of Set 5 | hasaki
# Processing Record 40 of Set 5 | galle
# Processing Record 41 of Set 5 | kaniama
# Processing Record 42 of Set 5 | wukari
# Processing Record 43 of Set 5 | qaqortoq
# Processing Record 44 of Set 5 | presidencia roque saenz pena
# Processing Record 45 of Set 5 | suntar
# Processing Record 46 of Set 5 | baykit
# Processing Record 47 of Set 5 | tommot
# Processing Record 48 of Set 5 | tabory
# Processing Record 49 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 5 | lensk
# Processing Record 1 of Set 6 | bulawayo
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | bucerias
# Processing Record 4 of Set 6 | namatanai
# Processing Record 5 of Set 6 | joaima
# Processing Record 6 of Set 6 | kudahuvadhoo
# Processing Record 7 of Set 6 | erenhot
# Processing Record 8 of Set 6 | gunjur
# Processing Record 9 of Set 6 | kismayo
# Processing Record 10 of Set 6 | great yarmouth
# Processing Record 11 of Set 6 | kodiak
# Processing Record 12 of Set 6 | gillette
# Processing Record 13 of Set 6 | saravan
# Processing Record 14 of Set 6 | gurskoye
# City not found. Skipping...
# Processing Record 15 of Set 6 | parana
# Processing Record 16 of Set 6 | aksu
# Processing Record 17 of Set 6 | porto belo
# Processing Record 18 of Set 6 | nantucket
# Processing Record 19 of Set 6 | zhaotong
# Processing Record 20 of Set 6 | norman wells
# Processing Record 21 of Set 6 | road town
# Processing Record 22 of Set 6 | konstantinovka
# Processing Record 23 of Set 6 | vao
# Processing Record 24 of Set 6 | laukaa
# Processing Record 25 of Set 6 | atambua
# Processing Record 26 of Set 6 | koboldo
# City not found. Skipping...
# Processing Record 27 of Set 6 | cabadiangan
# Processing Record 28 of Set 6 | ponta do sol
# Processing Record 29 of Set 6 | san
# Processing Record 30 of Set 6 | cornwall
# Processing Record 31 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 6 | shingu
# Processing Record 33 of Set 6 | padang
# Processing Record 34 of Set 6 | tongliao
# Processing Record 35 of Set 6 | kruisfontein
# Processing Record 36 of Set 6 | madera
# Processing Record 37 of Set 6 | rach gia
# Processing Record 38 of Set 6 | san quintin
# Processing Record 39 of Set 6 | mokrous
# Processing Record 40 of Set 6 | pangoa
# Processing Record 41 of Set 6 | marawi
# Processing Record 42 of Set 6 | kimbe
# Processing Record 43 of Set 6 | ellisras
# Processing Record 44 of Set 6 | karpinsk
# Processing Record 45 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 46 of Set 6 | cidreira
# Processing Record 47 of Set 6 | tuatapere
# Processing Record 48 of Set 6 | kisangani
# Processing Record 49 of Set 6 | nouadhibou
# Processing Record 50 of Set 6 | vilcun
# Processing Record 1 of Set 7 | general pico
# Processing Record 2 of Set 7 | moshkovo
# Processing Record 3 of Set 7 | antofagasta
# Processing Record 4 of Set 7 | rocha
# Processing Record 5 of Set 7 | waddan
# Processing Record 6 of Set 7 | tynda
# Processing Record 7 of Set 7 | cedar city
# Processing Record 8 of Set 7 | kavaratti
# Processing Record 9 of Set 7 | ust-kuyga
# Processing Record 10 of Set 7 | pacifica
# Processing Record 11 of Set 7 | dalen
# Processing Record 12 of Set 7 | adrar
# Processing Record 13 of Set 7 | el alto
# Processing Record 14 of Set 7 | capreol
# Processing Record 15 of Set 7 | dandong
# Processing Record 16 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 17 of Set 7 | acapulco
# Processing Record 18 of Set 7 | zhigansk
# Processing Record 19 of Set 7 | wagar
# Processing Record 20 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 7 | ribeira brava
# Processing Record 22 of Set 7 | richards bay
# Processing Record 23 of Set 7 | pangnirtung
# Processing Record 24 of Set 7 | zlobin
# Processing Record 25 of Set 7 | tanshui
# City not found. Skipping...
# Processing Record 26 of Set 7 | tuktoyaktuk
# Processing Record 27 of Set 7 | rosetta
# Processing Record 28 of Set 7 | tingrela
# City not found. Skipping...
# Processing Record 29 of Set 7 | selikhino
# Processing Record 30 of Set 7 | ancud
# Processing Record 31 of Set 7 | port hardy
# Processing Record 32 of Set 7 | boden
# Processing Record 33 of Set 7 | yumen
# Processing Record 34 of Set 7 | kinsale
# Processing Record 35 of Set 7 | hanting
# Processing Record 36 of Set 7 | harper
# Processing Record 37 of Set 7 | havre-saint-pierre
# Processing Record 38 of Set 7 | gizo
# Processing Record 39 of Set 7 | lebu
# Processing Record 40 of Set 7 | bilibino
# Processing Record 41 of Set 7 | ostrovnoy
# Processing Record 42 of Set 7 | manavalakurichi
# Processing Record 43 of Set 7 | jiwani
# Processing Record 44 of Set 7 | zhuhai
# Processing Record 45 of Set 7 | mogadishu
# Processing Record 46 of Set 7 | carnarvon
# Processing Record 47 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 7 | chernyshevskiy
# Processing Record 49 of Set 7 | khandyga
# Processing Record 50 of Set 7 | puerto carreno
# Processing Record 1 of Set 8 | ihosy
# Processing Record 2 of Set 8 | namikupa
# Processing Record 3 of Set 8 | solwezi
# Processing Record 4 of Set 8 | cayenne
# Processing Record 5 of Set 8 | ojinaga
# Processing Record 6 of Set 8 | lysva
# Processing Record 7 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 8 of Set 8 | asyut
# Processing Record 9 of Set 8 | surt
# Processing Record 10 of Set 8 | galesong
# Processing Record 11 of Set 8 | araguaina
# Processing Record 12 of Set 8 | kloulklubed
# Processing Record 13 of Set 8 | merauke
# Processing Record 14 of Set 8 | high level
# Processing Record 15 of Set 8 | ardesen
# Processing Record 16 of Set 8 | canals
# Processing Record 17 of Set 8 | la ronge
# Processing Record 18 of Set 8 | hambantota
# Processing Record 19 of Set 8 | vanimo
# Processing Record 20 of Set 8 | povenets
# Processing Record 21 of Set 8 | aguililla
# Processing Record 22 of Set 8 | zhezkazgan
# Processing Record 23 of Set 8 | samarai
# Processing Record 24 of Set 8 | gambela
# Processing Record 25 of Set 8 | riyadh
# Processing Record 26 of Set 8 | balod
# Processing Record 27 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 28 of Set 8 | westport
# Processing Record 29 of Set 8 | tomatlan
# Processing Record 30 of Set 8 | cangzhou
# Processing Record 31 of Set 8 | hithadhoo
# Processing Record 32 of Set 8 | baherden
# Processing Record 33 of Set 8 | sola
# Processing Record 34 of Set 8 | haines junction
# Processing Record 35 of Set 8 | arzgir
# Processing Record 36 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 37 of Set 8 | malindi
# Processing Record 38 of Set 8 | kasempa
# Processing Record 39 of Set 8 | montlucon
# Processing Record 40 of Set 8 | beloha
# Processing Record 41 of Set 8 | inhambane
# Processing Record 42 of Set 8 | kabo
# Processing Record 43 of Set 8 | codrington
# Processing Record 44 of Set 8 | xacmaz
# Processing Record 45 of Set 8 | te anau
# Processing Record 46 of Set 8 | haicheng
# Processing Record 47 of Set 8 | raudeberg
# Processing Record 48 of Set 8 | magole
# Processing Record 49 of Set 8 | opuwo
# Processing Record 50 of Set 8 | kodinsk
# Processing Record 1 of Set 9 | waw
# Processing Record 2 of Set 9 | hounde
# Processing Record 3 of Set 9 | ust-ishim
# Processing Record 4 of Set 9 | hot springs
# Processing Record 5 of Set 9 | kununurra
# Processing Record 6 of Set 9 | marquette
# Processing Record 7 of Set 9 | natal
# Processing Record 8 of Set 9 | djenne
# Processing Record 9 of Set 9 | buraydah
# Processing Record 10 of Set 9 | kuito
# Processing Record 11 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 9 | vestmannaeyjar
# Processing Record 13 of Set 9 | khorramshahr
# Processing Record 14 of Set 9 | comodoro rivadavia
# Processing Record 15 of Set 9 | soyo
# Processing Record 16 of Set 9 | kotido
# Processing Record 17 of Set 9 | qasigiannguit
# Processing Record 18 of Set 9 | gravelbourg
# Processing Record 19 of Set 9 | atar
# Processing Record 20 of Set 9 | shu
# Processing Record 21 of Set 9 | aksha
# Processing Record 22 of Set 9 | varias
# Processing Record 23 of Set 9 | halifax
# Processing Record 24 of Set 9 | camacha
# Processing Record 25 of Set 9 | waipawa
# Processing Record 26 of Set 9 | catabola
# Processing Record 27 of Set 9 | grindavik
# Processing Record 28 of Set 9 | banes
# Processing Record 29 of Set 9 | toguchin
# Processing Record 30 of Set 9 | meulaboh
# Processing Record 31 of Set 9 | qostanay
# Processing Record 32 of Set 9 | carutapera
# Processing Record 33 of Set 9 | roseburg
# Processing Record 34 of Set 9 | padilla
# Processing Record 35 of Set 9 | morgan city
# Processing Record 36 of Set 9 | mahibadhoo
# Processing Record 37 of Set 9 | coihueco
# Processing Record 38 of Set 9 | shiyan
# Processing Record 39 of Set 9 | bom jesus da lapa
# Processing Record 40 of Set 9 | kingman
# Processing Record 41 of Set 9 | southbridge
# Processing Record 42 of Set 9 | karla
# Processing Record 43 of Set 9 | christchurch
# Processing Record 44 of Set 9 | sabha
# Processing Record 45 of Set 9 | souillac
# Processing Record 46 of Set 9 | soure
# Processing Record 47 of Set 9 | kursk
# Processing Record 48 of Set 9 | camocim
# Processing Record 49 of Set 9 | cedar lake
# Processing Record 50 of Set 9 | finschhafen
# Processing Record 1 of Set 10 | almaznyy
# Processing Record 2 of Set 10 | porto velho
# Processing Record 3 of Set 10 | fort-de-france
# Processing Record 4 of Set 10 | jasidih
# Processing Record 5 of Set 10 | abalak
# Processing Record 6 of Set 10 | brae
# Processing Record 7 of Set 10 | sawakin
# Processing Record 8 of Set 10 | hofn
# Processing Record 9 of Set 10 | vicuna
# Processing Record 10 of Set 10 | beamsville
# Processing Record 11 of Set 10 | kidal
# Processing Record 12 of Set 10 | muhos
# Processing Record 13 of Set 10 | guanica
# Processing Record 14 of Set 10 | manicore
# Processing Record 15 of Set 10 | ulundi
# Processing Record 16 of Set 10 | dasuya
# Processing Record 17 of Set 10 | kingisepp
# Processing Record 18 of Set 10 | san rafael
# Processing Record 19 of Set 10 | shumskiy
# Processing Record 20 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 10 | nioro
# Processing Record 22 of Set 10 | fort nelson
# Processing Record 23 of Set 10 | orsha
# Processing Record 24 of Set 10 | northam
# Processing Record 25 of Set 10 | hamilton
# Processing Record 26 of Set 10 | hauterive
# Processing Record 27 of Set 10 | bulgan
# Processing Record 28 of Set 10 | mugan
# Processing Record 29 of Set 10 | palmer
# Processing Record 30 of Set 10 | pacific grove
# Processing Record 31 of Set 10 | kirksville
# Processing Record 32 of Set 10 | minab
# Processing Record 33 of Set 10 | odweyne
# Processing Record 34 of Set 10 | lexington
# Processing Record 35 of Set 10 | korla
# Processing Record 36 of Set 10 | lahijan
# Processing Record 37 of Set 10 | port shepstone
# Processing Record 38 of Set 10 | kulhudhuffushi
# Processing Record 39 of Set 10 | mana
# Processing Record 40 of Set 10 | hengshui
# Processing Record 41 of Set 10 | capaci
# Processing Record 42 of Set 10 | neya
# Processing Record 43 of Set 10 | ratnagiri
# Processing Record 44 of Set 10 | sao filipe
# Processing Record 45 of Set 10 | yerbogachen
# Processing Record 46 of Set 10 | altamira
# Processing Record 47 of Set 10 | tucurui
# Processing Record 48 of Set 10 | naze
# Processing Record 49 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 10 | turgenevo
# Processing Record 1 of Set 11 | kaeo
# Processing Record 2 of Set 11 | coihaique
# Processing Record 3 of Set 11 | belyy yar
# Processing Record 4 of Set 11 | dalvik
# Processing Record 5 of Set 11 | iquitos
# Processing Record 6 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 7 of Set 11 | cache creek
# Processing Record 8 of Set 11 | oum hadjer
# Processing Record 9 of Set 11 | iskateley
# Processing Record 10 of Set 11 | hameenlinna
# Processing Record 11 of Set 11 | ulagan
# Processing Record 12 of Set 11 | troy
# Processing Record 13 of Set 11 | deputatskiy
# Processing Record 14 of Set 11 | macau
# Processing Record 15 of Set 11 | severo-yeniseyskiy
# Processing Record 16 of Set 11 | zaltan
# Processing Record 17 of Set 11 | eydhafushi
# Processing Record 18 of Set 11 | jalingo
# Processing Record 19 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 11 | kahului
# Processing Record 21 of Set 11 | dicabisagan
# Processing Record 22 of Set 11 | bam
# Processing Record 23 of Set 11 | pontianak
# Processing Record 24 of Set 11 | kortkeros
# Processing Record 25 of Set 11 | killybegs
# Processing Record 26 of Set 11 | shelburne
# Processing Record 27 of Set 11 | gallup
# Processing Record 28 of Set 11 | tiarei
# Processing Record 29 of Set 11 | jibuti
# Processing Record 30 of Set 11 | sangar
# Processing Record 31 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 11 | whitehorse
# Processing Record 33 of Set 11 | srednekolymsk
# Processing Record 34 of Set 11 | shuyskoye
# Processing Record 35 of Set 11 | feicheng
# Processing Record 36 of Set 11 | asau
# Processing Record 37 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 38 of Set 11 | bilma
# Processing Record 39 of Set 11 | puerto leguizamo
# Processing Record 40 of Set 11 | clyde river
# Processing Record 41 of Set 11 | oktyabrskiy
# Processing Record 42 of Set 11 | nipani
# Processing Record 43 of Set 11 | jumla
# Processing Record 44 of Set 11 | kachug
# Processing Record 45 of Set 11 | katherine
# Processing Record 46 of Set 11 | shache
# Processing Record 47 of Set 11 | airai
# Processing Record 48 of Set 11 | chandbali
# Processing Record 49 of Set 11 | kasamwa
# Processing Record 50 of Set 11 | shibarghan
# City not found. Skipping...
# Processing Record 1 of Set 12 | klaksvik
# Processing Record 2 of Set 12 | konevo
# Processing Record 3 of Set 12 | athens
# Processing Record 4 of Set 12 | paithan
# Processing Record 5 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 12 | tchibanga
# Processing Record 7 of Set 12 | rorvik
# Processing Record 8 of Set 12 | tupaciguara
# Processing Record 9 of Set 12 | caravelas
# Processing Record 10 of Set 12 | abu zabad
# Processing Record 11 of Set 12 | cabedelo
# Processing Record 12 of Set 12 | hay river
# Processing Record 13 of Set 12 | tome-acu
# City not found. Skipping...
# Processing Record 14 of Set 12 | wajima
# Processing Record 15 of Set 12 | thiers
# Processing Record 16 of Set 12 | burgersdorp
# Processing Record 17 of Set 12 | baijiantan
# Processing Record 18 of Set 12 | manyana
# Processing Record 19 of Set 12 | lata
# Processing Record 20 of Set 12 | oranjemund
# Processing Record 21 of Set 12 | semey
# Processing Record 22 of Set 12 | lokosovo
# Processing Record 23 of Set 12 | chippewa falls
# Processing Record 24 of Set 12 | cabo san lucas
# Processing Record 25 of Set 12 | sur
# Processing Record 26 of Set 12 | mayo
# Processing Record 27 of Set 12 | dalaba
# Processing Record 28 of Set 12 | hammond
# Processing Record 29 of Set 12 | ligayan
# Processing Record 30 of Set 12 | zomba
# Processing Record 31 of Set 12 | morondava
# Processing Record 32 of Set 12 | benjamin aceval
# Processing Record 33 of Set 12 | chaa-khol
# City not found. Skipping...
# Processing Record 34 of Set 12 | gagino
# Processing Record 35 of Set 12 | barentu
# Processing Record 36 of Set 12 | thornhill
# Processing Record 37 of Set 12 | kyenjojo
# Processing Record 38 of Set 12 | moose factory
# Processing Record 39 of Set 12 | praia da vitoria
# Processing Record 40 of Set 12 | necochea
# Processing Record 41 of Set 12 | bud
# Processing Record 42 of Set 12 | ipixuna
# Processing Record 43 of Set 12 | gavle
# Processing Record 44 of Set 12 | rawson
# Processing Record 45 of Set 12 | abu samrah
# Processing Record 46 of Set 12 | saint-augustin
# Processing Record 47 of Set 12 | zhirnovsk
# Processing Record 48 of Set 12 | evensk
# Processing Record 49 of Set 12 | kozhevnikovo
# Processing Record 50 of Set 12 | kamyshin
# Processing Record 1 of Set 13 | emerald
# Processing Record 2 of Set 13 | saint-denis
# Processing Record 3 of Set 13 | stornoway
# Processing Record 4 of Set 13 | moree
# Processing Record 5 of Set 13 | greenville
# Processing Record 6 of Set 13 | naryan-mar
# Processing Record 7 of Set 13 | dibaya
# City not found. Skipping...
# Processing Record 8 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 13 | sept-iles
# Processing Record 10 of Set 13 | ayorou
# Processing Record 11 of Set 13 | betsiamites
# Processing Record 12 of Set 13 | zhangye
# Processing Record 13 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 13 | ngunguru
# Processing Record 15 of Set 13 | jarjis
# City not found. Skipping...
# Processing Record 16 of Set 13 | disna
# Processing Record 17 of Set 13 | brazzaville
# Processing Record 18 of Set 13 | kyzyl-suu
# Processing Record 19 of Set 13 | samana
# Processing Record 20 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 13 | flinders
# Processing Record 22 of Set 13 | luwuk
# Processing Record 23 of Set 13 | dodge city
# Processing Record 24 of Set 13 | beyneu
# Processing Record 25 of Set 13 | calahorra
# Processing Record 26 of Set 13 | dingle
# Processing Record 27 of Set 13 | roros
# Processing Record 28 of Set 13 | warrnambool
# Processing Record 29 of Set 13 | george
# Processing Record 30 of Set 13 | nanakuli
# Processing Record 31 of Set 13 | uberlandia
# Processing Record 32 of Set 13 | jacareacanga
# Processing Record 33 of Set 13 | puerto penasco
# Processing Record 34 of Set 13 | nhulunbuy
# Processing Record 35 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 36 of Set 13 | asuncion mita
# Processing Record 37 of Set 13 | cap malheureux
# Processing Record 38 of Set 13 | mahanoro
# Processing Record 39 of Set 13 | mocuba
# Processing Record 40 of Set 13 | falmouth
# Processing Record 41 of Set 13 | mathathane
# Processing Record 42 of Set 13 | dunedin
# Processing Record 43 of Set 13 | kalmunai
# Processing Record 44 of Set 13 | popondetta
# Processing Record 45 of Set 13 | kuala terengganu
# Processing Record 46 of Set 13 | moroni
# Processing Record 47 of Set 13 | banamba
# Processing Record 48 of Set 13 | margate
# Processing Record 49 of Set 13 | birjand
# Processing Record 50 of Set 13 | dongkan
# Processing Record 1 of Set 14 | samur
# Processing Record 2 of Set 14 | dunmore town
# Processing Record 3 of Set 14 | mattru
# Processing Record 4 of Set 14 | sidi qasim
# City not found. Skipping...
# Processing Record 5 of Set 14 | sechura
# Processing Record 6 of Set 14 | ekhabi
# Processing Record 7 of Set 14 | teneguiban
# City not found. Skipping...
# Processing Record 8 of Set 14 | abu dhabi
# Processing Record 9 of Set 14 | maniitsoq
# Processing Record 10 of Set 14 | henties bay
# Processing Record 11 of Set 14 | healdsburg
# Processing Record 12 of Set 14 | tezu
# Processing Record 13 of Set 14 | dudinka
# Processing Record 14 of Set 14 | doha
# Processing Record 15 of Set 14 | kamenka
# Processing Record 16 of Set 14 | morant bay
# Processing Record 17 of Set 14 | araouane
# Processing Record 18 of Set 14 | golden
# Processing Record 19 of Set 14 | liverpool
# Processing Record 20 of Set 14 | port hawkesbury
# Processing Record 21 of Set 14 | ketrzyn
# Processing Record 22 of Set 14 | rio gallegos
# Processing Record 23 of Set 14 | sitka
# Processing Record 24 of Set 14 | angoram
# Processing Record 25 of Set 14 | vila velha
# Processing Record 26 of Set 14 | chimore
# Processing Record 27 of Set 14 | warangal
# Processing Record 28 of Set 14 | visaginas
# Processing Record 29 of Set 14 | yenagoa
# Processing Record 30 of Set 14 | sabang
# Processing Record 31 of Set 14 | santa luzia
# Processing Record 32 of Set 14 | bezhanitsy
# Processing Record 33 of Set 14 | matara
# Processing Record 34 of Set 14 | tonantins
# Processing Record 35 of Set 14 | haysville
# Processing Record 36 of Set 14 | molfetta
# Processing Record 37 of Set 14 | qui nhon
# Processing Record 38 of Set 14 | bonthe
# Processing Record 39 of Set 14 | west wendover
# Processing Record 40 of Set 14 | agadez
# Processing Record 41 of Set 14 | yauya
# Processing Record 42 of Set 14 | guhagar
# Processing Record 43 of Set 14 | harboore
# Processing Record 44 of Set 14 | siniscola
# Processing Record 45 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 14 | pochutla
# Processing Record 47 of Set 14 | khilok
# Processing Record 48 of Set 14 | yar-sale
# Processing Record 49 of Set 14 | ha giang
# Processing Record 50 of Set 14 | tuam
# Processing Record 1 of Set 15 | sindou
# Processing Record 2 of Set 15 | shenjiamen
# Processing Record 3 of Set 15 | neuquen
# Processing Record 4 of Set 15 | palestina
# Processing Record 5 of Set 15 | tawang
# Processing Record 6 of Set 15 | raton
# Processing Record 7 of Set 15 | sioux lookout
# Processing Record 8 of Set 15 | calvinia
# Processing Record 9 of Set 15 | vardo
# Processing Record 10 of Set 15 | campoverde
# Processing Record 11 of Set 15 | teguise
# Processing Record 12 of Set 15 | ilebo
# Processing Record 13 of Set 15 | deloraine
# Processing Record 14 of Set 15 | san carlos de bariloche
# Processing Record 15 of Set 15 | sao luiz gonzaga
# Processing Record 16 of Set 15 | geraldton
# Processing Record 17 of Set 15 | dukstas
# Processing Record 18 of Set 15 | el limon
# Processing Record 19 of Set 15 | gazanjyk
# Processing Record 20 of Set 15 | puerto madryn
# Processing Record 21 of Set 15 | turbat
# Processing Record 22 of Set 15 | belaya gora
# Processing Record 23 of Set 15 | nemuro
# Processing Record 24 of Set 15 | victor harbor
# Processing Record 25 of Set 15 | ruteng
# Processing Record 26 of Set 15 | west odessa
# Processing Record 27 of Set 15 | lubao
# Processing Record 28 of Set 15 | hyeres
# Processing Record 29 of Set 15 | fukue
# Processing Record 30 of Set 15 | ambilobe
# Processing Record 31 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 15 | asosa
# Processing Record 33 of Set 15 | loudi
# Processing Record 34 of Set 15 | narkevychi
# Processing Record 35 of Set 15 | chelno-vershiny
# Processing Record 36 of Set 15 | dezhou
# Processing Record 37 of Set 15 | basco
# Processing Record 38 of Set 15 | do rud
# City not found. Skipping...
# Processing Record 39 of Set 15 | at-bashi
# Processing Record 40 of Set 15 | viedma
# Processing Record 41 of Set 15 | flin flon
# Processing Record 42 of Set 15 | fare
# Processing Record 43 of Set 15 | hovd
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 683

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nikolskoye  59.7035   30.7861     19.78        96          63
# 1      Tasiilaq  65.6145  -37.6368     16.50        67         100
# 2    Chokurdakh  70.6333  147.9167    -28.37       100          97
# 3     Busselton -33.6500  115.3333     66.58        76           0
# 4       Ushuaia -54.8000  -68.3000     60.46        55          75
# 5  Saint George  37.1041 -113.5841     45.95        35           0
# 6  Puerto Ayora  -0.7393  -90.3518     80.56        93          55
# 7          Tura  25.5198   90.2201     57.76        57          67
# 8     Saskylakh  71.9167  114.0833     -6.43        79         100
# 9        Avarua -21.2078 -159.7750     82.45        74          40
#
#    Wind Speed Country Current Description
# 0        6.22      RU       broken clouds
# 1        6.58      GL     overcast clouds
# 2        2.91      RU     overcast clouds
# 3       17.25      AU           clear sky
# 4        5.75      AR       moderate rain
# 5        8.05      US           clear sky
# 6        8.99      EC       broken clouds
# 7        3.33      IN       broken clouds
# 8        3.62      RU     overcast clouds
# 9        5.75      CK          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:

column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Nikolskoye      RU  59.7035   30.7861     19.78        96          63
# 1    Tasiilaq      GL  65.6145  -37.6368     16.50        67         100
# 2  Chokurdakh      RU  70.6333  147.9167    -28.37       100          97
# 3   Busselton      AU -33.6500  115.3333     66.58        76           0
# 4     Ushuaia      AR -54.8000  -68.3000     60.46        55          75
#
#    Wind Speed Current Description
# 0        6.22       broken clouds
# 1        6.58     overcast clouds
# 2        2.91     overcast clouds
# 3       17.25           clear sky
# 4        5.75       moderate rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"


# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
